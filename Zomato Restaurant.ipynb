# %%
# SOLVE THE REGRESSION PROBLEM (PREDICTING AVERAGE COST FOR TWO)

# Import the necessary Liabrary from the system

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the data from the given path and convert into the Data Frame.

df=pd.read_excel(r"C:\Users\acer\OneDrive\Desktop\DATA TRAINED\Internship\Evaluation Projects\Country-Code.xlsx")

# It will show top five elements of the DataFrame

df.tail()
# Out:
#     Country Code         Country
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df.shape
# Out:
# (15, 2)

# %%
# Read the data from the given path and convert into the Data Frame.

df1=pd.read_csv(r'C:\Users\acer\OneDrive\Desktop\DATA TRAINED\Internship\Evaluation Projects\zomato.csv',encoding=('ISO-8859-1'))

# It will show top five elements of the DataFrame

df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1.shape
# Out:
# (9551, 21)

# %%
# Merge both the dataframe using merge method.

data=pd.merge(df,df1)
data.head()
# Out:
#    Country Code Country  Restaurant ID                        Restaurant Name  \
# 0             1   India        3400025                             Jahanpanah
# 1             1   India        3400341                    Rangrezz Restaurant
# 2             1   India        3400005                Time2Eat - Mama Chicken
# 3             1   India        3400021  Chokho Jeeman Marwari Jain Bhojanalya
# 4             1   India        3400017                         Pinch Of Spice
#
#    City                                            Address     Locality  \
# 0  Agra  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 1  Agra  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 2  Agra        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 3  Agra  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 4  Agra  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
# ...

# %%
data.shape
# Out:
# (9551, 22)

# %%
# It will show the list of unique element containing by each column

for i in data:
    print(data[i].unique())
# Out:
# [  1  14  30  37  94 148 162 166 184 189 191 208 214 215 216]
# ['India' 'Australia' 'Brazil' 'Canada' 'Indonesia' 'New Zealand'
#  'Phillipines' 'Qatar' 'Singapore' 'South Africa' 'Sri Lanka' 'Turkey'
#  'UAE' 'United Kingdom' 'United States']
# [ 3400025  3400341  3400005 ... 17697332 17694056 17559793]
# ['Jahanpanah' 'Rangrezz Restaurant' 'Time2Eat - Mama Chicken' ...
#  'Tokyo Japanese Steak House' "Theo Yianni's Authentic Greek Restaurant"
#  "Fishpatrick's Crabby Cafe"]
# ['Agra' 'Ahmedabad' 'Allahabad' 'Amritsar' 'Aurangabad' 'Bangalore'
#  'Bhopal' 'Bhubaneshwar' 'Chandigarh' 'Chennai' 'Coimbatore' 'Dehradun'
#  'Faridabad' 'Ghaziabad' 'Goa' 'Gurgaon' 'Guwahati' 'Hyderabad' 'Indore'
#  'Jaipur' 'Kanpur' 'Kochi' 'Kolkata' 'Lucknow' 'Ludhiana' 'Mangalore'
#  'Mohali' 'Mumbai' 'Mysore' 'Nagpur' 'Nashik' 'New Delhi' 'Noida'
#  'Panchkula' 'Patna' 'Puducherry' 'Pune' 'Ranchi' 'Secunderabad' 'Surat'
#  'Vadodara' 'Varanasi' 'Vizag' 'Armidale' 'Balingup' 'Beechworth'
# ...

# %%
data.nunique()
# Out:
# Country Code              15
# Country                   15
# Restaurant ID           9551
# Restaurant Name         7446
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# dtype: int64

# %%
# It will show the list of unique element containing by each column

for i in data:
    print(data[i].value_counts())
# Out:
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# 214      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 166      20
# 184      20
# 191      20
# 37        4
# Name: count, dtype: int64
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64
# Restaurant ID
# 3400025     1
# 309811      1
# 18460981    1
# 18287389    1
# 1629        1
#            ..
# 4096        1
# 18358700    1
# 2217        1
# 18398571    1
# 17559793    1
# Name: count, Length: 9551, dtype: int64
# Restaurant Name
# Cafe Coffee Day                       83
# ...

# %%
data.drop('Switch to order menu',axis=1,inplace=True)

# %%
data.info() # Data type is ok
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   object
#  2   Restaurant ID         9551 non-null   int64
#  3   Restaurant Name       9551 non-null   object
#  4   City                  9551 non-null   object
#  5   Address               9551 non-null   object
#  6   Locality              9551 non-null   object
#  7   Locality Verbose      9551 non-null   object
#  8   Longitude             9551 non-null   float64
#  9   Latitude              9551 non-null   float64
#  10  Cuisines              9542 non-null   object
#  11  Average Cost for two  9551 non-null   int64
#  12  Currency              9551 non-null   object
#  13  Has Table booking     9551 non-null   object
#  14  Has Online delivery   9551 non-null   object
# ...

# %%
data.isnull().sum() # Cuisine contain the null value
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Impute the null values of descreate data.

from sklearn.impute import SimpleImputer

si_imp=SimpleImputer(strategy='most_frequent')
fil_null=si_imp.fit_transform(data[['Cuisines','Currency']])
d2=pd.DataFrame(fil_null)
d2
# Out:
#                                    0                   1
# 0              North Indian, Mughlai  Indian Rupees(Rs.)
# 1              North Indian, Mughlai  Indian Rupees(Rs.)
# 2                       North Indian  Indian Rupees(Rs.)
# 3                         Rajasthani  Indian Rupees(Rs.)
# 4     North Indian, Chinese, Mughlai  Indian Rupees(Rs.)
# ...                              ...                 ...
# 9546              American, Bar Food           Dollar($)
# 9547                            Thai           Dollar($)
# 9548          Japanese, Steak, Sushi           Dollar($)
# 9549         Burger, Greek, Sandwich           Dollar($)
# 9550          Burger, Seafood, Steak           Dollar($)
#
# [9551 rows x 2 columns]

# %%
data[['Cuisines','Currency']]=d2
data
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# ...

# %%
data.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# It will tell the short story about the dataset.

data.describe()
# Out:
#        Country Code  Restaurant ID    Longitude     Latitude  \
# count   9551.000000   9.551000e+03  9551.000000  9551.000000
# mean      18.365616   9.051128e+06    64.126574    25.854381
# std       56.750546   8.791521e+06    41.467058    11.007935
# min        1.000000   5.300000e+01  -157.948486   -41.330428
# 25%        1.000000   3.019625e+05    77.081343    28.478713
# 50%        1.000000   6.004089e+06    77.191964    28.570469
# 75%        1.000000   1.835229e+07    77.282006    28.642758
# max      216.000000   1.850065e+07   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# Split Numerical data and Categorical Data
# It will tell these are the categorical column in dataset

categorical_object=[]
for i in data.dtypes.index:
    if data.dtypes[i]=='object':
        categorical_object.append(i)      
print("Categorical Data",categorical_object)
# Out:
# Categorical Data ['Country', 'Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Rating color', 'Rating text']

# %%
# It will tell these are the numerical column in dataset

numerical_object=[]
for i in data.dtypes.index:
    if (data.dtypes[i]!='object'):
        numerical_object.append(i) 
print("Numerical Data\n",numerical_object)
# Out:
# Numerical Data
#  ['Country Code', 'Restaurant ID', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
# After go through the dataset we assume something that skewness and outliers is there so now we analyse the data to check 
# howmuch our assumption is correct
# Here we check how data is distributed, it is normally distributed or not.

plt.figure(figsize=(20,20),facecolor='yellow')
number=1
for i in numerical_object:
    if number<=8:
        ax=plt.subplot(2,4,number)
        sns.distplot(data[i])
        plt.xlabel(i,fontsize=10)
    number+=1
plt.show()

# %%
plt.figure(figsize=(20,15),facecolor='yellow')
number=1
for i in numerical_object:
    if number<=8:
        ax=plt.subplot(2,4,number)
        sns.boxplot(data[i])
        plt.xlabel(i,fontsize=10)
    number+=1
plt.show()

# %%
# Find the standard number of outlier and remove it

from scipy.stats import zscore

z_score=zscore(data[['Longitude', 'Latitude','Aggregate rating','Votes']])
data1=np.abs(z_score)
filter_data=(data1<3).all(axis=1)
df2=data[filter_data]
df2
# Out:
#       Country Code         Country  Restaurant ID  \
# 0                1           India        3400025
# 1                1           India        3400341
# 2                1           India        3400005
# 3                1           India        3400021
# 4                1           India        3400017
# ...            ...             ...            ...
# 9112           215  United Kingdom        6800892
# 9113           215  United Kingdom        6800263
# 9114           215  United Kingdom        6801039
# 9115           215  United Kingdom        6801873
# 9116           215  United Kingdom        6800782
#
#                                Restaurant Name        City  \
# 0                                   Jahanpanah        Agra
# 1                          Rangrezz Restaurant        Agra
# 2                      Time2Eat - Mama Chicken        Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya        Agra
# 4                               Pinch Of Spice        Agra
# ...

# %%
# After go through the dataset we assume something that skewness and outliers is there so now we analyse the data to check 
# howmuch our assumption is correct
# Here we check how data is distributed, it is normally distributed or not.

plt.figure(figsize=(20,20),facecolor='yellow')
number=1
for i in numerical_object:
    if number<=8:
        ax=plt.subplot(2,4,number)
        sns.distplot(df2[i])
        plt.xlabel(i,fontsize=10)
    number+=1
plt.show()

# %%
# Encoding the data 

from sklearn.preprocessing import LabelEncoder
lab_end=LabelEncoder()
for i in categorical_object:  
    df2[i]=lab_end.fit_transform(df2[i])
df2.head()
# Out:
#    Country Code  Country  Restaurant ID  Restaurant Name  City  Address  \
# 0             1        0        3400025             2887     1     3939
# 1             1        0        3400341             4779     1     3990
# 2             1        0        3400005             6287     1     5575
# 3             1        0        3400021             1502     1       95
# 4             1        0        3400017             4452     1     1086
#
#    Locality  Locality Verbose  Longitude   Latitude  ...  \
# 0        15                15  78.011544  27.161661  ...
# 1        15                15   0.000000   0.000000  ...
# 2        15                15  78.011608  27.160832  ...
# 3       160               161  77.998092  27.195928  ...
# 4       160               161  78.007553  27.201725  ...
#
#    Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 0                   850         3                  0                    0
# ...

# %%
df2.shape
# Out:
# (8772, 21)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8772 entries, 0 to 9116
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          8772 non-null   int64
#  1   Country               8772 non-null   int32
#  2   Restaurant ID         8772 non-null   int64
#  3   Restaurant Name       8772 non-null   int32
#  4   City                  8772 non-null   int32
#  5   Address               8772 non-null   int32
#  6   Locality              8772 non-null   int32
#  7   Locality Verbose      8772 non-null   int32
#  8   Longitude             8772 non-null   float64
#  9   Latitude              8772 non-null   float64
#  10  Cuisines              8772 non-null   int32
#  11  Average Cost for two  8772 non-null   int64
#  12  Currency              8772 non-null   int32
#  13  Has Table booking     8772 non-null   int32
#  14  Has Online delivery   8772 non-null   int32
# ...

# %%
# Check the corelation and relationship b/w data (feature and Target)

plt.figure(figsize=(20,15))
sns.heatmap(df2.corr().abs(),annot=True)
plt.show()

# In this heapmap we can see there is corelation b/w country code and country so we recheck then we delete one of them

# %%
# Separate Input and Output Variable

x=df2.drop(['Average Cost for two'],axis=1)
y=df2['Average Cost for two']

# %%
x
# Out:
#       Country Code  Country  Restaurant ID  Restaurant Name  City  Address  \
# 0                1        0        3400025             2887     1     3939
# 1                1        0        3400341             4779     1     3990
# 2                1        0        3400005             6287     1     5575
# 3                1        0        3400021             1502     1       95
# 4                1        0        3400017             4452     1     1086
# ...            ...      ...            ...              ...   ...      ...
# 9112           215        9        6800892             2340    38     1319
# 9113           215        9        6800263              195    38     2314
# 9114           215        9        6801039             5017    38     1805
# 9115           215        9        6801873             3893    38     7903
# 9116           215        9        6800782             5996    38     7903
#
# ...

# %%
# Now we check the relation b/w Input and Output Variable

plt.figure(figsize=(30,30),facecolor='yellow')
number=1
for i in x:
    if number<=20:
        ax=plt.subplot(5,4,number)
        plt.scatter(x[i],y)
        plt.xlabel(i,fontsize=20)
        plt.ylabel('Average Cost for two',fontsize=25)
    number+=1
plt.show()

# After go through the graph i am not getting any clearity so we can not remove any feature data on the basis of assumption 
# untill we are not sure.

# %%
# Select the feature which have most significant relation with the target variable.
from sklearn.feature_selection import SelectKBest,f_classif

best_features= SelectKBest(score_func=f_classif,k=15)                                                     
fit=best_features.fit(x,y)                           
                                                                                                 
df_scores=pd.DataFrame(fit.scores_)                  
df_columns=pd.DataFrame(x.columns)

# concatenate dataframes

features_score=pd.concat([df_columns,df_scores],axis=1)
features_score.columns= ['Features_Name','Score']
print(features_score.nlargest(15,'Score'))
# Out:
#           Features_Name       Score
# 15          Price range  702.988827
# 1               Country  164.588895
# 0          Country Code  131.326893
# 12    Has Table booking   76.954894
# 11             Currency   37.032213
# 19                Votes   23.637952
# 16     Aggregate rating   18.553641
# 8             Longitude   10.280088
# 9              Latitude   10.116704
# 13  Has Online delivery    9.680622
# 18          Rating text    4.872016
# 4                  City    4.322508
# 2         Restaurant ID    3.453597
# 17         Rating color    3.362687
# 6              Locality    2.882318

# %%
new_x=x[['Price range','Country','Country Code','Has Table booking','Currency','Votes','Aggregate rating','Longitude',
                   'Latitude','Has Online delivery','Rating text','City','Restaurant ID','Rating color','Locality']]
new_x
# Out:
#       Price range  Country  Country Code  Has Table booking  Currency  Votes  \
# 0               3        0             1                  0         3    140
# 1               2        0             1                  0         3     71
# 2               2        0             1                  0         3     94
# 3               2        0             1                  0         3     87
# 4               3        0             1                  0         3    177
# ...           ...      ...           ...                ...       ...    ...
# 9112            4        9           215                  0         6    602
# 9113            2        9           215                  0         6    383
# 9114            2        9           215                  0         6    745
# 9115            3        9           215                  1         6     67
# 9116            4        9           215                  0         6    114
#
# ...

# %%
# Now standarised the data means take all data on one scale.

from sklearn.preprocessing import StandardScaler

x_scaler=StandardScaler()
x_scaler=x_scaler.fit_transform(new_x)
x_scaler
# Out:
# array([[ 1.44425958, -0.1671959 , -0.17582363, ..., -0.60462577,
#          1.39112894, -2.08616386],
#        [ 0.29503561, -0.1671959 , -0.17582363, ..., -0.60459015,
#          1.39112894, -2.08616386],
#        [ 0.29503561, -0.1671959 , -0.17582363, ..., -0.60462802,
#          1.39112894, -2.08616386],
#        ...,
#        [ 0.29503561,  7.17417327,  6.1427597 , ..., -0.2213016 ,
#         -1.42988085,  1.14807557],
#        [ 1.44425958,  7.17417327,  6.1427597 , ..., -0.2212076 ,
#         -1.42988085,  1.36643824],
#        [ 2.59348355,  7.17417327,  6.1427597 , ..., -0.22133056,
#         -1.42988085,  1.36643824]])

# %%
# Check the multicolinarity

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x_scaler,i) for i in range(x_scaler.shape[1])]
vif["Features"]=new_x.columns # to show all feature
vif                                                                  

# multicolinarity is there
# Out:
#           vif             Features
# 0    1.965819          Price range
# 1   65.085465              Country
# 2   56.304966         Country Code
# 3    1.549139    Has Table booking
# 4    1.930303             Currency
# 5    1.609647                Votes
# 6    2.013813     Aggregate rating
# 7    5.245217            Longitude
# 8    5.209617             Latitude
# 9    1.146592  Has Online delivery
# 10   1.514755          Rating text
# 11   1.098572                 City
# 12   1.274455        Restaurant ID
# 13   1.230667         Rating color
# 14   1.043075             Locality

# %%
new_x.drop('Country',axis=1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

x_scaler=StandardScaler()
x_scaler=x_scaler.fit_transform(new_x)
x_scaler
# Out:
# array([[ 1.44425958, -0.17582363, -0.37747188, ..., -0.60462577,
#          1.39112894, -2.08616386],
#        [ 0.29503561, -0.17582363, -0.37747188, ..., -0.60459015,
#          1.39112894, -2.08616386],
#        [ 0.29503561, -0.17582363, -0.37747188, ..., -0.60462802,
#          1.39112894, -2.08616386],
#        ...,
#        [ 0.29503561,  6.1427597 , -0.37747188, ..., -0.2213016 ,
#         -1.42988085,  1.14807557],
#        [ 1.44425958,  6.1427597 ,  2.64920394, ..., -0.2212076 ,
#         -1.42988085,  1.36643824],
#        [ 2.59348355,  6.1427597 , -0.37747188, ..., -0.22133056,
#         -1.42988085,  1.36643824]])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x_scaler,i) for i in range(x_scaler.shape[1])]
vif["Features"]=new_x.columns 
vif             
# Remove multicolinarity
# Out:
#          vif             Features
# 0   1.965265          Price range
# 1   1.671614         Country Code
# 2   1.541934    Has Table booking
# 3   1.793117             Currency
# 4   1.603257                Votes
# 5   2.007317     Aggregate rating
# 6   2.263080            Longitude
# 7   2.201139             Latitude
# 8   1.146211  Has Online delivery
# 9   1.506722          Rating text
# 10  1.087335                 City
# 11  1.273196        Restaurant ID
# 12  1.230657         Rating color
# 13  1.042517             Locality

# %%
# Split the dataset into Training and Test Data

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,test_size=.25,random_state=50000)

# %%
# As it is Regression Problem so we use Regression Models
# Linear Regression Model

from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Now we evaluate the model using metrics that how model is performing.

from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
y_pred=lin_reg.predict(x_test)
y_pred
# Out:
# array([ 6687.30249584,    49.25924808, -3412.58795949, ...,
#          262.40749978,  3172.83294103,   150.15949051])

# %%
r1=r2_score(y_test,y_pred)
r1
# Out:
# 0.14490041961390476

# %%
mae1=mean_absolute_error(y_test,y_pred)
mae1
# Out:
# 1789.7914922654222

# %%
mse1=mean_squared_error(y_test,y_pred)
mse1
# Out:
# 68805001.0596064

# %%
rmse1=np.sqrt(mean_squared_error(y_test,y_pred))
rmse1
# Out:
# 8294.87800149022

# %%
# RMSE is low but we will recheck using graph

plt.scatter(x=y_test,y=y_pred)

# %%
# Linear Regression Model is not looking so we will try some other model

# %%
# Decision Tree Regressor Model

from sklearn.tree import DecisionTreeRegressor

dectree=DecisionTreeRegressor()
dectree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
pred1=dectree.predict(x_test)
pred1
# Out:
# array([500., 100., 500., ..., 650., 600., 450.])

# %%
r2=r2_score(y_test,pred1)
r2
# Out:
# 0.5756616691333419

# %%
mae2=mean_absolute_error(y_test,pred1)
mae2
# Out:
# 385.1618787049704

# %%
mse2=mean_squared_error(y_test,pred1)
mse2
# Out:
# 34144092.65845873

# %%
rmse2=np.sqrt(mean_squared_error(y_test,pred1))
rmse2
# Out:
# 5843.294674963666

# %%
# RMSE is high so model is not performing good but we will recheck using graph

plt.scatter(x=y_test,y=pred1)

# %%
# This Model is not looking so we will try some other model

# %%
# AdaBoost Regressor Model

from sklearn.ensemble import AdaBoostRegressor

# %%
ada=AdaBoostRegressor()
ada.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
pred2=ada.predict(x_test)
pred2
# Out:
# array([609.09550046, 413.77299002, 609.09550046, ..., 609.09550046,
#        609.09550046, 413.77299002])

# %%
r3=r2_score(y_test,pred2)
r3
# Out:
# 0.7264215996191563

# %%
mae3=mean_absolute_error(y_test,pred2)
mae3
# Out:
# 380.9583359005292

# %%
mse3=mean_squared_error(y_test,pred2)
mse3
# Out:
# 22013298.286955234

# %%
rmse3=np.sqrt(mean_squared_error(y_test,pred2))
rmse3
# Out:
# 4691.833147817091

# %%
# RMSE is high so model is not performing good but we will recheck using graph

plt.scatter(x=y_test,y=pred2)

# %%
# This Model is not looking so we will try some other model

# %%
# Random Forest Regression Model

from sklearn.ensemble import RandomForestRegressor
ran_forst=RandomForestRegressor()
ran_forst.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred3=ran_forst.predict(x_test)
pred3
# Out:
# array([512. , 260.5, 492.2, ..., 638. , 634.5, 404. ])

# %%
r4=r2_score(y_test,pred3)
r4
# Out:
# 0.7582343951194288

# %%
mae4=mean_absolute_error(y_test,pred3)
mae4
# Out:
# 284.4751937984496

# %%
mse4=mean_squared_error(y_test,pred3)
mse4
# Out:
# 19453503.523499772

# %%
rmse4=np.sqrt(mean_squared_error(y_test,pred3))
rmse4
# Out:
# 4410.612601838861

# %%
# RMSE is high so model is not performing good but we will recheck using graph
plt.scatter(x=y_test,y=pred2)

# %%
# This Model is not looking so we will try some other model

# %%
# KNN Regressor Model

from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
pred4=knn.predict(x_test)
pred4
# Out:
# array([590., 240., 360., ..., 640., 620., 390.])

# %%
r5=r2_score(y_test,pred4)
r5
# Out:
# 0.4148087924737929

# %%
mae5=mean_absolute_error(y_test,pred4)
mae5
# Out:
# 391.27450980392155

# %%
mse5=mean_squared_error(y_test,pred4)
mse5
# Out:
# 47087009.019151844

# %%
rmse5=np.sqrt(mean_squared_error(y_test,pred4))
rmse5
# Out:
# 6861.99745111814

# %%
# RMSE is low so model can be good but we will recheck using graph

plt.scatter(x=y_test,y=pred4)

# %%
# This Model is performing better tha other models but we will try some other model also

# %%
# Gradient Boosting Regressor Model

from sklearn.ensemble import GradientBoostingRegressor
gbdt=GradientBoostingRegressor()
gbdt.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
pred5=gbdt.predict(x_test)
pred5
# Out:
# array([493.14033617, 287.85251645, 535.44250099, ..., 614.3921644 ,
#        679.65020292, 328.110227  ])

# %%
r6=r2_score(y_test,pred5)
r6
# Out:
# 0.6965536731569213

# %%
mae6=mean_absolute_error(y_test,pred5)
mae6
# Out:
# 315.4014193612568

# %%
mse6=mean_squared_error(y_test,pred5)
mse6
# Out:
# 24416600.497622233

# %%
rmse6=np.sqrt(mean_squared_error(y_test,pred5))
rmse6
# Out:
# 4941.315664640565

# %%
# RMSE is so high so we will recheck using graph

plt.scatter(x=y_test,y=pred5)

# %%
# This Model is not looking so we will try some other model

# %%
# SVR Model

from sklearn.svm import SVR
svr=SVR()  
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
pred6=svr.predict(x_test)
pred6
# Out:
# array([531.36922908, 406.72470502, 563.52917487, ..., 543.30989014,
#        643.32215039, 396.85501071])

# %%
r7=r2_score(y_test,pred6)
r7
# Out:
# -0.00014912736826855344

# %%
mae7=mean_absolute_error(y_test,pred6)
mae7
# Out:
# 582.3253125499607

# %%
mse7=mean_squared_error(y_test,pred6)
mse7
# Out:
# 80476313.34033236

# %%
rmse7=np.sqrt(mean_squared_error(y_test,pred6))
rmse7
# Out:
# 8970.859119411716

# %%
# RMSE is high but we will recheck using graph

plt.scatter(x=y_test,y=pred5)

# %%
models = pd.DataFrame({'Model': ['Linear_Regression','Decision Tree','AdaBoost','Random_Forest','KNN_Model','GBDT',
                                 'Support Vector Machines'],
                       'R2 Score Result':[r1,r2,r3,r4,r5,r6,r7],'MAE Result':[mae1,mae2,mae3,mae4,mae5,mae6,mae7],
                       'MSE Result':[mse1,mse2,mse3,mse4,mse5,mse6,mse7],'RMSE Result':[rmse1,rmse2,rmse3,rmse4,rmse5,
                                                                                       rmse6,rmse7]})                     
models
# Out:
#                      Model  R2 Score Result   MAE Result    MSE Result  \
# 0        Linear_Regression         0.144900  1789.791492  6.880500e+07
# 1            Decision Tree         0.575662   385.161879  3.414409e+07
# 2                 AdaBoost         0.726422   380.958336  2.201330e+07
# 3            Random_Forest         0.758234   284.475194  1.945350e+07
# 4                KNN_Model         0.414809   391.274510  4.708701e+07
# 5                     GBDT         0.696554   315.401419  2.441660e+07
# 6  Support Vector Machines        -0.000149   582.325313  8.047631e+07
#
#    RMSE Result
# 0  8294.878001
# 1  5843.294675
# 2  4691.833148
# 3  4410.612602
# 4  6861.997451
# 5  4941.315665
# 6  8970.859119

# %%
# In above DataFrame we can see Random Forest Model is Performing better than other models

# %%
params={'n_estimators':[5,10],'max_depth':[10,15],'min_samples_leaf':[5,8],
        'min_samples_split':[10,15]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search= GridSearchCV(ran_forst,param_grid=params,cv=5)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [10, 15], 'min_samples_leaf': [5, 8],
#                          'min_samples_split': [10, 15],
#                          'n_estimators': [5, 10]})

# %%
grid_search.best_params_
# Out:
# {'max_depth': 15,
#  'min_samples_leaf': 5,
#  'min_samples_split': 15,
#  'n_estimators': 5}

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=15,
#                       n_estimators=5)

# %%
# Final Model

final_model=RandomForestRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=15,n_estimators=10)
final_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=15,
#                       n_estimators=10)

# %%
predd=final_model.predict(x_test)
predd
# Out:
# array([502.46681016, 286.44186217, 476.98051236, ..., 617.4846068 ,
#        680.89576419, 406.70637124])

# %%
r2_score(y_test,predd)
# Out:
# 0.6825070248607694

# %%
mean_absolute_error(y_test,predd)
# Out:
# 295.482217561165

# %%
mean_squared_error(y_test,predd)
# Out:
# 25546854.41549255

# %%
np.sqrt(mean_squared_error(y_test,predd))
# Out:
# 5054.389618489314

# %%
# Prediction 2 : Price Range

# %%
df2
# Out:
#       Country Code  Country  Restaurant ID  Restaurant Name  City  Address  \
# 0                1        0        3400025             2887     1     3939
# 1                1        0        3400341             4779     1     3990
# 2                1        0        3400005             6287     1     5575
# 3                1        0        3400021             1502     1       95
# 4                1        0        3400017             4452     1     1086
# ...            ...      ...            ...              ...   ...      ...
# 9112           215        9        6800892             2340    38     1319
# 9113           215        9        6800263              195    38     2314
# 9114           215        9        6801039             5017    38     1805
# 9115           215        9        6801873             3893    38     7903
# 9116           215        9        6800782             5996    38     7903
#
#       Locality  Locality Verbose  Longitude   Latitude  ...  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8772 entries, 0 to 9116
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          8772 non-null   int64
#  1   Country               8772 non-null   int32
#  2   Restaurant ID         8772 non-null   int64
#  3   Restaurant Name       8772 non-null   int32
#  4   City                  8772 non-null   int32
#  5   Address               8772 non-null   int32
#  6   Locality              8772 non-null   int32
#  7   Locality Verbose      8772 non-null   int32
#  8   Longitude             8772 non-null   float64
#  9   Latitude              8772 non-null   float64
#  10  Cuisines              8772 non-null   int32
#  11  Average Cost for two  8772 non-null   int64
#  12  Currency              8772 non-null   int32
#  13  Has Table booking     8772 non-null   int32
#  14  Has Online delivery   8772 non-null   int32
# ...

# %%
df2.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Separate Input and Output Variable

x=df2.drop(['Price range'],axis=1)
y=df2['Price range']

# %%
# Now we check the relation b/w Input and Output Variable

plt.figure(figsize=(30,30),facecolor='yellow')
number=1
for i in x:
    if number<=20:
        ax=plt.subplot(6,4,number)
        plt.scatter(x[i],y)
        plt.xlabel(i,fontsize=20)
        plt.ylabel('Price Range',fontsize=25)
    number+=1
plt.show()

# After go through the graph i am not getting any clearity so we can not remove any feature data on the basis of assumption 
# untill we are not sure.

# %%
# Now standarised the data means take all data on one scale.

from sklearn.preprocessing import StandardScaler

x_scaler=StandardScaler()
x_scaler=x_scaler.fit_transform(x)
x_scaler
# Out:
# array([[-0.17582363, -0.1671959 , -0.60462577, ...,  1.39112894,
#          0.19941974,  0.21346607],
#        [-0.17582363, -0.1671959 , -0.60459015, ...,  1.39112894,
#          0.19941974, -0.14877409],
#        [-0.17582363, -0.1671959 , -0.60462802, ...,  1.39112894,
#          0.19941974, -0.02802737],
#        ...,
#        [ 6.1427597 ,  7.17417327, -0.2213016 , ..., -1.42988085,
#          2.03436025,  3.38962979],
#        [ 6.1427597 ,  7.17417327, -0.2212076 , ..., -1.42988085,
#          2.03436025, -0.16977352],
#        [ 6.1427597 ,  7.17417327, -0.22133056, ..., -1.42988085,
#          2.03436025,  0.07696978]])

# %%
# Check the multicolinarity

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x_scaler,i) for i in range(x_scaler.shape[1])]
vif["Features"]=x.columns # to show all feature
vif                                                                  

# multicolinarity is there
# Out:
#            vif              Features
# 0    57.711768          Country Code
# 1    66.406124               Country
# 2     1.293597         Restaurant ID
# 3     1.007579       Restaurant Name
# 4     1.111661                  City
# 5     1.060535               Address
# 6   621.747595              Locality
# 7   621.710983      Locality Verbose
# 8     5.275632             Longitude
# 9     5.229901              Latitude
# 10    1.027440              Cuisines
# 11    1.160687  Average Cost for two
# 12    1.961021              Currency
# 13    1.138675     Has Table booking
# 14    1.158139   Has Online delivery
# 15    1.014522     Is delivering now
# 16    1.891493      Aggregate rating
# 17    1.234571          Rating color
# 18    1.497252           Rating text
# 19    1.597983                 Votes

# %%
x.drop('Locality',axis=1,inplace=True)

# %%
# Now standarised the data means take all data on one scale.

from sklearn.preprocessing import StandardScaler

x_scaler=StandardScaler()
x_scaler=x_scaler.fit_transform(x)
x_scaler
# Out:
# array([[-0.17582363, -0.1671959 , -0.60462577, ...,  1.39112894,
#          0.19941974,  0.21346607],
#        [-0.17582363, -0.1671959 , -0.60459015, ...,  1.39112894,
#          0.19941974, -0.14877409],
#        [-0.17582363, -0.1671959 , -0.60462802, ...,  1.39112894,
#          0.19941974, -0.02802737],
#        ...,
#        [ 6.1427597 ,  7.17417327, -0.2213016 , ..., -1.42988085,
#          2.03436025,  3.38962979],
#        [ 6.1427597 ,  7.17417327, -0.2212076 , ..., -1.42988085,
#          2.03436025, -0.16977352],
#        [ 6.1427597 ,  7.17417327, -0.22133056, ..., -1.42988085,
#          2.03436025,  0.07696978]])

# %%
# Check the multicolinarity

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x_scaler,i) for i in range(x_scaler.shape[1])]
vif["Features"]=x.columns # to show all feature
vif                                                                  

# multicolinarity is there
# Out:
#           vif              Features
# 0   57.703447          Country Code
# 1   66.399803               Country
# 2    1.293552         Restaurant ID
# 3    1.007578       Restaurant Name
# 4    1.104583                  City
# 5    1.059069               Address
# 6    1.060280      Locality Verbose
# 7    5.274758             Longitude
# 8    5.229574              Latitude
# 9    1.027023              Cuisines
# 10   1.160687  Average Cost for two
# 11   1.960615              Currency
# 12   1.138638     Has Table booking
# 13   1.157715   Has Online delivery
# 14   1.014522     Is delivering now
# 15   1.891239      Aggregate rating
# 16   1.234310          Rating color
# 17   1.497090           Rating text
# 18   1.595377                 Votes

# %%
x.drop('Country',axis=1,inplace=True)

# %%
# Now standarised the data means take all data on one scale.

from sklearn.preprocessing import StandardScaler

x_scaler=StandardScaler()
x_scaler=x_scaler.fit_transform(x)
x_scaler
# Out:
# array([[-0.17582363, -0.60462577, -0.21759883, ...,  1.39112894,
#          0.19941974,  0.21346607],
#        [-0.17582363, -0.60459015,  0.75642139, ...,  1.39112894,
#          0.19941974, -0.14877409],
#        [-0.17582363, -0.60462802,  1.53275463, ...,  1.39112894,
#          0.19941974, -0.02802737],
#        ...,
#        [ 6.1427597 , -0.2213016 ,  0.87894613, ..., -1.42988085,
#          2.03436025,  3.38962979],
#        [ 6.1427597 , -0.2212076 ,  0.30029987, ..., -1.42988085,
#          2.03436025, -0.16977352],
#        [ 6.1427597 , -0.22133056,  1.38294497, ..., -1.42988085,
#          2.03436025,  0.07696978]])

# %%
# Check the multicolinarity

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x_scaler,i) for i in range(x_scaler.shape[1])]
vif["Features"]=x.columns # to show all feature
vif
# Out:
#          vif              Features
# 0   1.624142          Country Code
# 1   1.292668         Restaurant ID
# 2   1.007534       Restaurant Name
# 3   1.091881                  City
# 4   1.057340               Address
# 5   1.059975      Locality Verbose
# 6   2.451391             Longitude
# 7   2.397615              Latitude
# 8   1.026848              Cuisines
# 9   1.139866  Average Cost for two
# 10  1.841586              Currency
# 11  1.133554     Has Table booking
# 12  1.157374   Has Online delivery
# 13  1.014474     Is delivering now
# 14  1.884522      Aggregate rating
# 15  1.234285          Rating color
# 16  1.489155           Rating text
# 17  1.587425                 Votes

# %%
# Split the dataset into Training and Test Data

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,test_size=.25,random_state=2)

# %%
# Knn Model to Solve Classification Problem

from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score,precision_score, recall_score,f1_score

# %%
test_pred=knn.predict(x_test)
test_pred
# Out:
# array([2, 1, 2, ..., 1, 1, 1], dtype=int64)

# %%
conf_mat=confusion_matrix(y_test,test_pred)
conf_mat
# Out:
# array([[833, 205,   5,   0],
#        [330, 320,  53,   9],
#        [ 45,  75, 168,  25],
#        [ 15,  27,  39,  44]], dtype=int64)

# %%
test_accu_score1=accuracy_score(y_test,test_pred)
test_accu_score1
# Out:
# 0.6224350205198358

# %%
test_accu_scoree1=recall_score(y_test,test_pred,average='macro')
test_accu_scoree1
# Out:
# 0.534209283606376

# %%
test_accu_scoreee1=precision_score(y_test,test_pred,average='macro')
test_accu_scoreee1
# Out:
# 0.5973859185084207

# %%
test_accu_scorre1=f1_score(y_test,test_pred,average='macro')
test_accu_scorre1
# Out:
# 0.5569993223043986

# %%
from sklearn.metrics import classification_report

# %%
class_rep=classification_report(y_test,test_pred)
print(class_rep)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.68      0.80      0.74      1043
#            2       0.51      0.45      0.48       712
#            3       0.63      0.54      0.58       313
#            4       0.56      0.35      0.43       125
#
#     accuracy                           0.62      2193
#    macro avg       0.60      0.53      0.56      2193
# weighted avg       0.61      0.62      0.61      2193

# %%
# Decision Tree model

from sklearn.tree import DecisionTreeClassifier
dec_tree=DecisionTreeClassifier()
dec_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
test_pred2=dec_tree.predict(x_test)
test_pred2
# Out:
# array([1, 2, 2, ..., 2, 1, 1], dtype=int64)

# %%
conf_mat=confusion_matrix(y_test,test_pred2)
conf_mat
# Out:
# array([[1039,    4,    0,    0],
#        [  10,  698,    4,    0],
#        [   0,   16,  291,    6],
#        [   0,    0,   16,  109]], dtype=int64)

# %%
test_accu_score3=accuracy_score(y_test,test_pred2)
test_accu_score3
# Out:
# 0.9744642042863657

# %%
test_accu_scoree3=recall_score(y_test,test_pred2,average='macro')
test_accu_scoree3
# Out:
# 0.9445536119080424

# %%
test_accu_scoreee3=precision_score(y_test,test_pred2,average='macro')
test_accu_scoreee3
# Out:
# 0.961532340903987

# %%
test_accu_scorre3=f1_score(y_test,test_pred2,average='macro')
test_accu_scorre3
# Out:
# 0.9526393141593905

# %%
# Random Forest Model

from sklearn.ensemble import RandomForestClassifier
ran_fort=RandomForestClassifier()
ran_fort.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
test_pred3=ran_fort.predict(x_test)
test_pred3
# Out:
# array([1, 2, 2, ..., 2, 1, 1], dtype=int64)

# %%
conf_mat=confusion_matrix(y_test,test_pred3)
conf_mat
# Out:
# array([[1042,    1,    0,    0],
#        [  12,  697,    3,    0],
#        [   0,   17,  287,    9],
#        [   0,    3,   21,  101]], dtype=int64)

# %%
test_accu_score4=accuracy_score(y_test,test_pred3,)
test_accu_score4
# Out:
# 0.9699042407660738

# %%
test_accu_scoree4=recall_score(y_test,test_pred3,average='macro')
test_accu_scoree4
# Out:
# 0.9257266797117631

# %%
test_accu_scoreee4=precision_score(y_test,test_pred3,average='macro')
test_accu_scoreee4
# Out:
# 0.9500945725177228

# %%
test_accu_scorre4=f1_score(y_test,test_pred3,average='macro')
test_accu_scorre4
# Out:
# 0.9370180263506216

# %%
# Suppport Vector Machine Model

from sklearn.svm import SVC
svc=SVC()  
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
test_pred4=svc.predict(x_test)
test_pred4
# Out:
# array([2, 2, 1, ..., 1, 1, 1], dtype=int64)

# %%
conf_mat=confusion_matrix(y_test,test_pred4)
conf_mat
# Out:
# array([[890, 151,   2,   0],
#        [328, 310,  71,   3],
#        [ 26,  70, 200,  17],
#        [ 12,  24,  58,  31]], dtype=int64)

# %%
test_accu_score5=accuracy_score(y_test,test_pred4)
test_accu_score5
# Out:
# 0.652530779753762

# %%
test_accu_scoree5=recall_score(y_test,test_pred4,average='macro')
test_accu_scoree5
# Out:
# 0.5439196650672895

# %%
test_accu_scoreee5=precision_score(y_test,test_pred4,average='macro')
test_accu_scoreee5
# Out:
# 0.6198075072947163

# %%
test_accu_scorre5=f1_score(y_test,test_pred4,average='macro')
test_accu_scorre5
# Out:
# 0.559246330675176

# %%
from sklearn.linear_model import LogisticRegression
lm=LogisticRegression()
lm.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
test_pred1=lm.predict(x_test)
test_pred1
# Out:
# array([2, 2, 1, ..., 1, 1, 1], dtype=int64)

# %%
conf_mat=confusion_matrix(y_test,test_pred1)
conf_mat
# Out:
# array([[942, 100,   1,   0],
#        [316, 350,  42,   4],
#        [  7, 129, 154,  23],
#        [  0,  40,  56,  29]], dtype=int64)

# %%
test_accu_score2=accuracy_score(y_test,test_pred1)
test_accu_score2
# Out:
# 0.6725946192430461

# %%
test_accu_scoree2=recall_score(y_test,test_pred1,average='macro')
test_accu_scoree2
# Out:
# 0.5296874408510992

# %%
test_accu_scoreee2=precision_score(y_test,test_pred1,average='macro')
test_accu_scoreee2
# Out:
# 0.6091612341265534

# %%
test_accu_scorre2=f1_score(y_test,test_pred1,average='macro')
test_accu_scorre2
# Out:
# 0.5517057805168276

# %%
models = pd.DataFrame({'Model': ['KNN Model','Logistic_Regression','Decision Tree','Random_Forest','Support Vector Machines'],
                       'Accuracy_score':[test_accu_score1,test_accu_score2,test_accu_score3,test_accu_score4,test_accu_score5],
                       'Recall_Score' :[test_accu_scoree1,test_accu_scoree2,test_accu_scoree3,test_accu_scoree4,test_accu_scoree5],
                       'Precision':[test_accu_scoreee1,test_accu_scoreee2,test_accu_scoreee3,test_accu_scoreee4,test_accu_scoreee5],
                      'F1_Score':[test_accu_scorre1,test_accu_scorre2,test_accu_scorre3,test_accu_scorre4,test_accu_scorre5]})
                     
models
# Out:
#                      Model  Accuracy_score  Recall_Score  Precision  F1_Score
# 0                KNN Model        0.622435      0.534209   0.597386  0.556999
# 1      Logistic_Regression        0.672595      0.529687   0.609161  0.551706
# 2            Decision Tree        0.974464      0.944554   0.961532  0.952639
# 3            Random_Forest        0.969904      0.925727   0.950095  0.937018
# 4  Support Vector Machines        0.652531      0.543920   0.619808  0.559246

# %%
# Now as per above DataFrame report we can say Decision Tree Models are performing well now we select the best model out of 
# all using ROC AUC Metrics.

# %%
# Hyperparameter Tunnning for Random Forest Model

# %%
params={'criterion':["gini","entropy"],'max_depth':[10,15],'min_samples_leaf':[5,8],'min_samples_split':[10,15],
       'max_leaf_nodes':[10,15]}
params
# Out:
# {'criterion': ['gini', 'entropy'],
#  'max_depth': [10, 15],
#  'min_samples_leaf': [5, 8],
#  'min_samples_split': [10, 15],
#  'max_leaf_nodes': [10, 15]}

# %%
from sklearn.model_selection import GridSearchCV
grid_search=GridSearchCV(estimator=dec_tree,param_grid=params,cv=5)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 15], 'max_leaf_nodes': [10, 15],
#                          'min_samples_leaf': [5, 8],
#                          'min_samples_split': [10, 15]})

# %%
grid_search.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 10,
#  'max_leaf_nodes': 15,
#  'min_samples_leaf': 5,
#  'min_samples_split': 10}

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=10, max_leaf_nodes=15, min_samples_leaf=5,
#                        min_samples_split=10)

# %%
# Final Model

final_model=DecisionTreeClassifier(criterion='gini', max_depth=10, max_leaf_nodes=15,min_samples_leaf=5,
                                   min_samples_split=10)
final_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, max_leaf_nodes=15, min_samples_leaf=5,
#                        min_samples_split=10)

# %%
predd=ran_fort.predict(x_test)
predd
# Out:
# array([1, 2, 2, ..., 2, 1, 1], dtype=int64)

# %%
accuracy_score(y_test,predd)
# Out:
# 0.9699042407660738

# %%
recall_score(y_test,predd,average='macro')
# Out:
# 0.9257266797117631

# %%
precision_score(y_test,predd,average='macro')
# Out:
# 0.9500945725177228

# %%
f1_score(y_test,predd,average='macro')
# Out:
# 0.9370180263506216

# %%
# Now After Hypertunning we can also say model is not underfitted and overfitted so RFM Modelis the best model for this 
# Classification problem

# %%
# END OF THE PROJECT 3 OF PHASE 3
